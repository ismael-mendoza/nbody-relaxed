# %%
# %matplotlib inline

# %%
from relaxed import plotting
import matplotlib.pyplot as plt

# %%
plotting.set_rc()

# %%
plt.plot([0, 1], [0,1], c='r')
plt.title(r"$a$")
# Out:
# Text(0.5, 1.0, '$a$')
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fb778d4d040> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/miniconda3/envs/relaxed/lib/python3.8/site-packages/matplotlib/pyplot.py in post_execute()
#     136     def post_execute():
#     137         if matplotlib.is_interactive():
# --> 138             draw_all()
#     139
#     140     try:  # IPython >= 2
#
# ~/miniconda3/envs/relaxed/lib/python3.8/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     135         for manager in cls.get_all_fig_managers():
#     136             if force or manager.canvas.figure.stale:
# --> 137                 manager.canvas.draw_idle()
#     138
#     139
#
# ~/miniconda3/envs/relaxed/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
# ...
